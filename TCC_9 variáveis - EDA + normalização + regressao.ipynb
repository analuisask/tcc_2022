# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
tabelas = ['variaveis']
variaveis = pd.read_excel('Dados_-_novo.xlsx', engine="openpyxl")
print(variaveis)
# Out:
#                 MUNICIPIO  POP_EST  DENS_DEM   IDHM    PIBCAP  NRO_EMP  \
# 0         Abadia de Goiás     9158     46.85  0.708  26505.89      3.0
# 1     Abadia dos Dourados     7022      7.61  0.689  18353.48      1.0
# 2               Abadiânia    20873     15.08  0.689  16132.95      3.0
# 3                  Abaeté    23263     12.49  0.698  21286.43      1.0
# 4              Abaetetuba   160439     87.61  0.628   9046.13      1.0
# ...                   ...      ...       ...    ...       ...      ...
# 5565          Xique-Xique    46562      8.28  0.585   8442.06      0.0
# 5566               Zabelê     2269     18.97  0.623  10724.45      0.0
# 5567             Zacarias     2784      7.32  0.729  32979.59      0.0
# 5568              Zé Doca    52190     20.77  0.595   8429.40      1.0
# 5569               Zortéa     3432     15.77  0.761  21389.69      0.0
#
#       MASSA_PCAP  CUSTO_UNIM  MASSA_PCAP_POP  DESP_TOT_RSU
# 0          1.450     170.270           0.882    1188166.84
# 1          1.016     223.671           0.882    5208595.22
# 2          1.016     223.671           0.882    5208595.22
# 3          1.120     223.671           0.990     279000.00
# 4          0.910     136.400           0.920    5613966.00
# ...          ...         ...             ...           ...
# 5565       1.016     223.671           0.882    5208595.22
# 5566       1.330     223.671           1.330     756423.91
# 5567       0.820     223.671           0.820     107400.00
# 5568       1.340      58.090           1.320    2131452.00
# 5569       0.990     447.100           0.990     454051.12
#
# [5570 rows x 10 columns]

# %%
variaveis["NRO_EMP"] = variaveis["NRO_EMP"].replace('0', 1.697)
print(variaveis.isnull().sum())
# Out:
# MUNICIPIO         0
# POP_EST           0
# DENS_DEM          0
# IDHM              0
# PIBCAP            0
# NRO_EMP           0
# MASSA_PCAP        0
# CUSTO_UNIM        0
# MASSA_PCAP_POP    0
# DESP_TOT_RSU      0
# dtype: int64

# %%
print(variaveis.shape)
# Out:
# (5570, 10)

# %%
print(variaveis.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5570 entries, 0 to 5569
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   MUNICIPIO       5570 non-null   object
#  1   POP_EST         5570 non-null   int64
#  2   DENS_DEM        5570 non-null   float64
#  3   IDHM            5570 non-null   float64
#  4   PIBCAP          5570 non-null   float64
#  5   NRO_EMP         5570 non-null   float64
#  6   MASSA_PCAP      5570 non-null   float64
#  7   CUSTO_UNIM      5570 non-null   float64
#  8   MASSA_PCAP_POP  5570 non-null   float64
#  9   DESP_TOT_RSU    5570 non-null   float64
# dtypes: float64(8), int64(1), object(1)
# memory usage: 435.3+ KB
# None

# %%
pd.options.display.float_format = '{:.2f}'.format
variaveis.describe((), include='all')
# Out:
#         MUNICIPIO     POP_EST  DENS_DEM    IDHM    PIBCAP  NRO_EMP  \
# count        5570     5570.00   5570.00 5570.00   5570.00  5570.00
# unique       5297         NaN       NaN     NaN       NaN      NaN
# top     Bom Jesus         NaN       NaN     NaN       NaN      NaN
# freq            5         NaN       NaN     NaN       NaN      NaN
# mean          NaN    38297.60    108.20    0.66  23513.94     1.70
# std           NaN   224288.15    571.86    0.07  24238.46     9.48
# min           NaN      771.00      0.13    0.42   4788.18     0.00
# 50%           NaN    11732.00     24.40    0.67  17433.84     0.00
# max           NaN 12396372.00  13024.56    0.86 583171.85   532.00
#
#         MASSA_PCAP  CUSTO_UNIM  MASSA_PCAP_POP  DESP_TOT_RSU
# count      5570.00     5570.00         5570.00       5570.00
# unique         NaN         NaN             NaN           NaN
# top            NaN         NaN             NaN           NaN
# freq           NaN         NaN             NaN           NaN
# mean          1.02      223.67            0.88    5208595.22
# std           0.55      132.71            0.52   46800726.11
# min           0.03       10.00            0.03      12500.00
# 50%           0.99      223.67            0.86    1105360.00
# max           5.90     3912.29            6.62 2348522610.92

# %%
print(variaveis.median())
# Out:
# POP_EST            11732.00
# DENS_DEM              24.40
# IDHM                   0.67
# PIBCAP             17433.84
# NRO_EMP                0.00
# MASSA_PCAP             0.99
# CUSTO_UNIM           223.67
# MASSA_PCAP_POP         0.86
# DESP_TOT_RSU     1105360.00
# dtype: float64
# C:\Users\Ana Luisa Schneider\AppData\Local\Temp\ipykernel_10152\4120702748.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   print(variaveis.median())

# %%
print(variaveis.var())
# Out:
# POP_EST               50305175490.64
# DENS_DEM                   327023.99
# IDHM                            0.01
# PIBCAP                  587503092.51
# NRO_EMP                        89.94
# MASSA_PCAP                      0.31
# CUSTO_UNIM                  17612.08
# MASSA_PCAP_POP                  0.27
# DESP_TOT_RSU     2190307964854468.50
# dtype: float64
# C:\Users\Ana Luisa Schneider\AppData\Local\Temp\ipykernel_10152\2159711142.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   print(variaveis.var())

# %%
print(variaveis.columns)
# Out:
# Index(['MUNICIPIO', 'POP_EST', 'DENS_DEM', 'IDHM', 'PIBCAP', 'NRO_EMP',
#        'MASSA_PCAP', 'CUSTO_UNIM', 'MASSA_PCAP_POP', 'DESP_TOT_RSU'],
#       dtype='object')

# %%
variaveis.value_counts()
# Out:
# MUNICIPIO        POP_EST  DENS_DEM  IDHM  PIBCAP    NRO_EMP  MASSA_PCAP  CUSTO_UNIM  MASSA_PCAP_POP  DESP_TOT_RSU
# Abadia de Goiás  9158     46.85     0.71  26505.89  3.00     1.45        170.27      0.88            1188166.84      1
# Peritiba         2733     31.18     0.77  30218.70  0.00     0.48        223.67      0.32            193933.68       1
# Petrolina        359372   64.44     0.70  19445.59  11.00    1.28        90.62       1.10            26704724.10     1
# Pesqueira        68067    63.21     0.61  10269.85  0.00     0.28        223.67      0.22            2204362.36      1
# Pescaria Brava   10225    108.11    0.66  10010.84  3.00     0.56        223.67      0.44            639549.10       1
#                                                                                                                     ..
# Gastão Vidigal   4911     23.17     0.72  16095.70  0.00     0.69        120.94      0.62            223895.03       1
# Gaspar           71925    149.91    0.77  43487.46  14.00    0.88        203.27      0.72            7343891.46      1
# Garça            44429    77.60     0.77  26874.37  2.00     0.73        278.35      0.73            3764673.93      1
# Garuva           18816    29.41     0.72  60183.18  3.00     0.75        420.34      0.60            2250498.22      1
# Óleo             2447     13.49     0.73  32970.07  0.00     0.91        240.38      0.60            108135.00       1
# Length: 5570, dtype: int64

# %%
variaveis.corr()
# Out:
#                 POP_EST  DENS_DEM  IDHM  PIBCAP  NRO_EMP  MASSA_PCAP  \
# POP_EST            1.00      0.44  0.14    0.07     0.95        0.00
# DENS_DEM           0.44      1.00  0.18    0.08     0.43       -0.00
# IDHM               0.14      0.18  1.00    0.45     0.21       -0.08
# PIBCAP             0.07      0.08  0.45    1.00     0.12        0.01
# NRO_EMP            0.95      0.43  0.21    0.12     1.00       -0.01
# MASSA_PCAP         0.00     -0.00 -0.08    0.01    -0.01        1.00
# CUSTO_UNIM        -0.02     -0.02  0.06    0.08    -0.02       -0.22
# MASSA_PCAP_POP     0.03      0.03 -0.03    0.02     0.02        0.88
# DESP_TOT_RSU       0.95      0.37  0.11    0.07     0.86        0.01
#
#                 CUSTO_UNIM  MASSA_PCAP_POP  DESP_TOT_RSU
# POP_EST              -0.02            0.03          0.95
# DENS_DEM             -0.02            0.03          0.37
# IDHM                  0.06           -0.03          0.11
# PIBCAP                0.08            0.02          0.07
# NRO_EMP              -0.02            0.02          0.86
# MASSA_PCAP           -0.22            0.88          0.01
# CUSTO_UNIM            1.00           -0.24         -0.00
# MASSA_PCAP_POP       -0.24            1.00          0.03
# DESP_TOT_RSU         -0.00            0.03          1.00

# %%
import seaborn as sns
corr = variaveis.corr()
sns.heatmap(corr, annot=True, square=True)
plt.show()

# %%
variaveis.hist()
# Out:
# array([[<AxesSubplot:title={'center':'POP_EST'}>,
#         <AxesSubplot:title={'center':'DENS_DEM'}>,
#         <AxesSubplot:title={'center':'IDHM'}>],
#        [<AxesSubplot:title={'center':'PIBCAP'}>,
#         <AxesSubplot:title={'center':'NRO_EMP'}>,
#         <AxesSubplot:title={'center':'MASSA_PCAP'}>],
#        [<AxesSubplot:title={'center':'CUSTO_UNIM'}>,
#         <AxesSubplot:title={'center':'MASSA_PCAP_POP'}>,
#         <AxesSubplot:title={'center':'DESP_TOT_RSU'}>]], dtype=object)

# %%
##normalizar com scikit

# %%
import seaborn as sns
import sklearn

# %%
norm_sk=variaveis.copy()

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()

# %%
for col in ['POP_EST','DENS_DEM','IDHM','PIBCAP','MASSA_PCAP','CUSTO_UNIM', 'MASSA_PCAP_POP', 'DESP_TOT_RSU']:
 sc.fit(norm_sk[[col]])
 sc_vari2=sc.transform(norm_sk[[col]])
 sc_vari2 = sc_vari2.reshape(-1)
 sns.displot(sc_vari2)

# %%
#previsão

# %%
import sklearn.model_selection as ms
import sklearn.linear_model as lm
from sklearn.metrics import r2_score

# %%
x = variaveis.iloc[:, 1:-1].values
y = variaveis.iloc[:, 1:8].values

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test= ms.train_test_split(x,y,test_size=0.2,random_state=0)

# %%
print("x_train:",x_train.shape)
print("x_test:",x_test.shape)
print("y_train:",y_train.shape)
print("y_test:",y_test.shape)
# Out:
# x_train: (4456, 8)
# x_test: (1114, 8)
# y_train: (4456, 7)
# y_test: (1114, 7)

# %%
regressor = lm.LinearRegression()
regressor.fit(variaveis[['POP_EST','DENS_DEM','IDHM','PIBCAP','MASSA_PCAP','CUSTO_UNIM', 'MASSA_PCAP_POP', 'DESP_TOT_RSU']],variaveis.NRO_EMP)
# Out:
# LinearRegression()

# %%
print(y_test)
# Out:
# [[9.11000e+03 5.08000e+00 7.14000e-01 ... 1.00000e+00 1.01600e+00
#   2.23671e+02]
#  [1.72540e+04 5.43000e+00 5.89000e-01 ... 0.00000e+00 1.01600e+00
#   2.23671e+02]
#  [3.83100e+03 9.09000e+00 6.30000e-01 ... 0.00000e+00 4.30000e-01
#   2.77640e+02]
#  ...
#  [8.49800e+04 8.61900e+01 7.55000e-01 ... 1.70000e+01 6.00000e-01
#   2.23671e+02]
#  [1.26460e+04 4.70800e+01 5.49000e-01 ... 0.00000e+00 6.90000e-01
#   2.03990e+02]
#  [8.00620e+04 6.73100e+01 7.10000e-01 ... 5.00000e+00 1.65000e+00
#   2.23671e+02]]

# %%
y_pred = regressor.predict(x_test)
print(y_pred)
# Out:
# [28.20959768 27.8759465  34.29037745 ... 30.28602984 24.87671468
#  31.42984942]
# C:\Users\Ana Luisa Schneider\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
plt.scatter(y_test,y_pred);
plt.xlabel('Actual');
plt.ylabel('Predicted')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [48], line 1
# ----> 1 plt.scatter(y_test,y_pred);
#       2 plt.xlabel('Actual');
#       3 plt.ylabel('Predicted')
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\pyplot.py:2817, in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    2812 @_copy_docstring_and_deprecators(Axes.scatter)
#    2813 def scatter(
#    2814         x, y, s=None, c=None, marker=None, cmap=None, norm=None,
#    2815         vmin=None, vmax=None, alpha=None, linewidths=None, *,
#    2816         edgecolors=None, plotnonfinite=False, data=None, **kwargs):
# -> 2817     __ret = gca().scatter(
#    2818         x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
#    2819         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#    2820         edgecolors=edgecolors, plotnonfinite=plotnonfinite,
#    2821         **({"data": data} if data is not None else {}), **kwargs)
#    2822     sci(__ret)
#    2823     return __ret
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\__init__.py:1414, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1411 @functools.wraps(func)
#    1412 def inner(ax, *args, data=None, **kwargs):
#    1413     if data is None:
# -> 1414         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1416     bound = new_sig.bind(ax, *args, **kwargs)
#    1417     auto_label = (bound.arguments.get(label_namer)
#    1418                   or bound.kwargs.get(label_namer))
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\axes\_axes.py:4368, in Axes.scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, **kwargs)
#    4366 y = np.ma.ravel(y)
#    4367 if x.size != y.size:
# -> 4368     raise ValueError("x and y must be the same size")
#    4370 if s is None:
#    4371     s = (20 if rcParams['_internal.classic_mode'] else
#    4372          rcParams['lines.markersize'] ** 2.0)
#
# ValueError: x and y must be the same size
