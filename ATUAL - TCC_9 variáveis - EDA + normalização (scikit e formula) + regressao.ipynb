# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
tabelas = ['variaveis']
variaveis = pd.read_excel('Dados_-_novo.xlsx', engine="openpyxl")
print(variaveis)
# Out:
#                 MUNICIPIO  POP_EST  DENS_DEM  IDHM    PIBCAP  MASSA_PCAP  \
# 0         Abadia de Goiás     9158    46.850 0.708 26505.890       1.450
# 1     Abadia dos Dourados     7022     7.610 0.689 18353.480       1.016
# 2               Abadiânia    20873    15.080 0.689 16132.950       1.016
# 3                  Abaeté    23263    12.490 0.698 21286.430       1.120
# 4              Abaetetuba   160439    87.610 0.628  9046.130       0.910
# ...                   ...      ...       ...   ...       ...         ...
# 5565          Xique-Xique    46562     8.280 0.585  8442.060       1.016
# 5566               Zabelê     2269    18.970 0.623 10724.450       1.330
# 5567             Zacarias     2784     7.320 0.729 32979.590       0.820
# 5568              Zé Doca    52190    20.770 0.595  8429.400       1.340
# 5569               Zortéa     3432    15.770 0.761 21389.690       0.990
#
#       CUSTO_UNIM  MASSA_PCAP_POP  DESP_TOT_RSU  NRO_EMP
# ...

# %%
variaveis["NRO_EMP"] = variaveis["NRO_EMP"].replace('0', 1.697)
print(variaveis.isnull().sum())
# Out:
# MUNICIPIO         0
# POP_EST           0
# DENS_DEM          0
# IDHM              0
# PIBCAP            0
# MASSA_PCAP        0
# CUSTO_UNIM        0
# MASSA_PCAP_POP    0
# DESP_TOT_RSU      0
# NRO_EMP           0
# dtype: int64

# %%
print(variaveis.shape)
# Out:
# (5570, 10)

# %%
print(variaveis.columns)
# Out:
# Index(['MUNICIPIO', 'POP_EST', 'DENS_DEM', 'IDHM', 'PIBCAP', 'MASSA_PCAP',
#        'CUSTO_UNIM', 'MASSA_PCAP_POP', 'DESP_TOT_RSU', 'NRO_EMP'],
#       dtype='object')

# %%
print(variaveis.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5570 entries, 0 to 5569
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   MUNICIPIO       5570 non-null   object
#  1   POP_EST         5570 non-null   int64
#  2   DENS_DEM        5570 non-null   float64
#  3   IDHM            5570 non-null   float64
#  4   PIBCAP          5570 non-null   float64
#  5   MASSA_PCAP      5570 non-null   float64
#  6   CUSTO_UNIM      5570 non-null   float64
#  7   MASSA_PCAP_POP  5570 non-null   float64
#  8   DESP_TOT_RSU    5570 non-null   float64
#  9   NRO_EMP         5570 non-null   float64
# dtypes: float64(8), int64(1), object(1)
# memory usage: 435.3+ KB
# None

# %%
variaveis.value_counts()
# Out:
# MUNICIPIO        POP_EST  DENS_DEM  IDHM   PIBCAP     MASSA_PCAP  CUSTO_UNIM  MASSA_PCAP_POP  DESP_TOT_RSU  NRO_EMP
# Abadia de Goiás  9158     46.850    0.708  26505.890  1.450       170.270     0.882           1188166.840   3.000      1
# Peritiba         2733     31.180    0.766  30218.700  0.480       223.671     0.320           193933.680    0.000      1
# Petrolina        359372   64.440    0.697  19445.590  1.280       90.620      1.100           26704724.100  11.000     1
# Pesqueira        68067    63.210    0.610  10269.850  0.280       223.671     0.220           2204362.360   0.000      1
# Pescaria Brava   10225    108.105   0.659  10010.840  0.560       223.671     0.440           639549.100    3.000      1
#                                                                                                                       ..
# Gastão Vidigal   4911     23.170    0.723  16095.700  0.690       120.940     0.620           223895.030    0.000      1
# ...

# %%
pd.options.display.float_format = '{:.3f}'.format
variaveis.describe((), include='all')
# Out:
#         MUNICIPIO      POP_EST  DENS_DEM     IDHM     PIBCAP  MASSA_PCAP  \
# count        5570     5570.000  5570.000 5570.000   5570.000    5570.000
# unique       5297          NaN       NaN      NaN        NaN         NaN
# top     Bom Jesus          NaN       NaN      NaN        NaN         NaN
# freq            5          NaN       NaN      NaN        NaN         NaN
# mean          NaN    38297.601   108.202    0.659  23513.942       1.016
# std           NaN   224288.153   571.860    0.072  24238.463       0.553
# min           NaN      771.000     0.130    0.418   4788.180       0.030
# 50%           NaN    11732.000    24.400    0.665  17433.840       0.990
# max           NaN 12396372.000 13024.560    0.862 583171.850       5.900
#
#         CUSTO_UNIM  MASSA_PCAP_POP   DESP_TOT_RSU  NRO_EMP
# count     5570.000        5570.000       5570.000 5570.000
# unique         NaN             NaN            NaN      NaN
# top            NaN             NaN            NaN      NaN
# ...

# %%
print(variaveis.median())
# Out:
# POP_EST            11732.000
# DENS_DEM              24.400
# IDHM                   0.665
# PIBCAP             17433.840
# MASSA_PCAP             0.990
# CUSTO_UNIM           223.671
# MASSA_PCAP_POP         0.860
# DESP_TOT_RSU     1105360.000
# NRO_EMP                0.000
# dtype: float64
# C:\Users\Ana Luisa Schneider\AppData\Local\Temp\ipykernel_8128\4120702748.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   print(variaveis.median())

# %%
print(variaveis.var())
# Out:
# POP_EST               50305175490.645
# DENS_DEM                   327023.994
# IDHM                            0.005
# PIBCAP                  587503092.514
# MASSA_PCAP                      0.305
# CUSTO_UNIM                  17612.076
# MASSA_PCAP_POP                  0.269
# DESP_TOT_RSU     2190307964854468.500
# NRO_EMP                        89.937
# dtype: float64
# C:\Users\Ana Luisa Schneider\AppData\Local\Temp\ipykernel_8128\2159711142.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   print(variaveis.var())

# %%
variaveis.corr()
# Out:
#                 POP_EST  DENS_DEM   IDHM  PIBCAP  MASSA_PCAP  CUSTO_UNIM  \
# POP_EST           1.000     0.440  0.144   0.072       0.002      -0.024
# DENS_DEM          0.440     1.000  0.178   0.076      -0.001      -0.025
# IDHM              0.144     0.178  1.000   0.447      -0.085       0.056
# PIBCAP            0.072     0.076  0.447   1.000       0.015       0.080
# MASSA_PCAP        0.002    -0.001 -0.085   0.015       1.000      -0.219
# CUSTO_UNIM       -0.024    -0.025  0.056   0.080      -0.219       1.000
# MASSA_PCAP_POP    0.026     0.030 -0.025   0.024       0.879      -0.242
# DESP_TOT_RSU      0.946     0.369  0.109   0.070       0.009      -0.002
# NRO_EMP           0.946     0.434  0.212   0.125      -0.009      -0.020
#
#                 MASSA_PCAP_POP  DESP_TOT_RSU  NRO_EMP
# POP_EST                  0.026         0.946    0.946
# DENS_DEM                 0.030         0.369    0.434
# IDHM                    -0.025         0.109    0.212
# ...

# %%
import seaborn as sns
corr = variaveis.corr()
sns.heatmap(corr, vmin=-1, vmax=1, center=None, linewidths=.5, square=True)
plt.show()

# %%
variaveis.hist()
# Out:
# array([[<AxesSubplot:title={'center':'POP_EST'}>,
#         <AxesSubplot:title={'center':'DENS_DEM'}>,
#         <AxesSubplot:title={'center':'IDHM'}>],
#        [<AxesSubplot:title={'center':'PIBCAP'}>,
#         <AxesSubplot:title={'center':'MASSA_PCAP'}>,
#         <AxesSubplot:title={'center':'CUSTO_UNIM'}>],
#        [<AxesSubplot:title={'center':'MASSA_PCAP_POP'}>,
#         <AxesSubplot:title={'center':'DESP_TOT_RSU'}>,
#         <AxesSubplot:title={'center':'NRO_EMP'}>]], dtype=object)

# %%
p=sns.barplot(data=variaveis, x='NRO_EMP', y='POP_EST')
p.set_xticklabels(p.get_xticklabels(), rotation=90, horizontalalignment='right')
plt.show()

# %%
plt.scatter(variaveis['POP_EST'], variaveis['NRO_EMP'], color='red')
plt.title('Número empresas Vs População estimada', fontsize=12)
plt.xlabel('População estimada', fontsize=12)
plt.ylabel('Número empresas', fontsize=12)
plt.grid(True)
plt.show()

# %%
plt.scatter(variaveis['DENS_DEM'], variaveis['NRO_EMP'], color='red')
plt.title('Número empresas Vs Densidade demográfica', fontsize=12)
plt.xlabel('Densidade demográfica', fontsize=12)
plt.ylabel('Número empresas', fontsize=12)
plt.grid(True)
plt.show()

# %%
plt.scatter(variaveis['IDHM'], variaveis['NRO_EMP'], color='red')
plt.title('Número empresas Vs IDH município', fontsize=12)
plt.xlabel('IDH município', fontsize=12)
plt.ylabel('Número empresas', fontsize=12)
plt.grid(True)
plt.show()

# %%
plt.scatter(variaveis['PIBCAP'], variaveis['NRO_EMP'], color='red')
plt.title('Número empresas Vs PIB per capita', fontsize=12)
plt.xlabel('PIB per capita', fontsize=12)
plt.ylabel('Número empresas', fontsize=12)
plt.grid(True)
plt.show()

# %%
plt.scatter(variaveis['MASSA_PCAP'], variaveis['NRO_EMP'], color='red')
plt.title('Número empresas Vs Massa gerada per capita', fontsize=12)
plt.xlabel('Massa gerada per capita', fontsize=12)
plt.ylabel('Número empresas', fontsize=12)
plt.grid(True)
plt.show()

# %%
plt.scatter(variaveis['CUSTO_UNIM'], variaveis['NRO_EMP'], color='red')
plt.title('Número empresas Vs Custo unitário médio serviços', fontsize=12)
plt.xlabel('Custo unitário médio municípios', fontsize=12)
plt.ylabel('Número empresas', fontsize=12)
plt.grid(True)
plt.show()

# %%
plt.scatter(variaveis['MASSA_PCAP_POP'], variaveis['NRO_EMP'], color='red')
plt.title('Número empresas Vs Massa gerada per capita população atendida', fontsize=12)
plt.xlabel('Massa gerada per capita população atendida', fontsize=12)
plt.ylabel('Número empresas', fontsize=12)
plt.grid(True)
plt.show()

# %%
plt.scatter(variaveis['DESP_TOT_RSU'], variaveis['NRO_EMP'], color='red')
plt.title('Número empresas Vs Despesa total com resíduos sólidos urbanos', fontsize=12)
plt.xlabel('Despesa total com resíduos sólidos urbanos', fontsize=12)
plt.ylabel('Número empresas', fontsize=12)
plt.grid(True)
plt.show()

# %%
##normalizar com scikit

# %%
import seaborn as sns
import sklearn

# %%
norm_sk=variaveis.copy()

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()

# %%
for col in ['POP_EST','DENS_DEM','IDHM','PIBCAP','MASSA_PCAP','CUSTO_UNIM', 'MASSA_PCAP_POP', 'DESP_TOT_RSU']:
 sc.fit(norm_sk[[col]])
 sc_vari2=sc.transform(norm_sk[[col]])
 sc_vari2 = sc_vari2.reshape(-1)
 sns.displot(sc_vari2)

# %%
norm_sk.corr()
# Out:
#                 POP_EST  DENS_DEM   IDHM  PIBCAP  MASSA_PCAP  CUSTO_UNIM  \
# POP_EST           1.000     0.440  0.144   0.072       0.002      -0.024
# DENS_DEM          0.440     1.000  0.178   0.076      -0.001      -0.025
# IDHM              0.144     0.178  1.000   0.447      -0.085       0.056
# PIBCAP            0.072     0.076  0.447   1.000       0.015       0.080
# MASSA_PCAP        0.002    -0.001 -0.085   0.015       1.000      -0.219
# CUSTO_UNIM       -0.024    -0.025  0.056   0.080      -0.219       1.000
# MASSA_PCAP_POP    0.026     0.030 -0.025   0.024       0.879      -0.242
# DESP_TOT_RSU      0.946     0.369  0.109   0.070       0.009      -0.002
# NRO_EMP           0.946     0.434  0.212   0.125      -0.009      -0.020
#
#                 MASSA_PCAP_POP  DESP_TOT_RSU  NRO_EMP
# POP_EST                  0.026         0.946    0.946
# DENS_DEM                 0.030         0.369    0.434
# IDHM                    -0.025         0.109    0.212
# ...

# %%
norm_sk.hist()
# Out:
# array([[<AxesSubplot:title={'center':'POP_EST'}>,
#         <AxesSubplot:title={'center':'DENS_DEM'}>,
#         <AxesSubplot:title={'center':'IDHM'}>],
#        [<AxesSubplot:title={'center':'PIBCAP'}>,
#         <AxesSubplot:title={'center':'MASSA_PCAP'}>,
#         <AxesSubplot:title={'center':'CUSTO_UNIM'}>],
#        [<AxesSubplot:title={'center':'MASSA_PCAP_POP'}>,
#         <AxesSubplot:title={'center':'DESP_TOT_RSU'}>,
#         <AxesSubplot:title={'center':'NRO_EMP'}>]], dtype=object)

# %%
plt.scatter(norm_sk['POP_EST'], norm_sk['NRO_EMP'], color='red')
plt.title('Número empresas Vs População estimada', fontsize=12)
plt.xlabel('População estimada', fontsize=12)
plt.ylabel('Número empresas', fontsize=12)
plt.grid(True)
plt.show()

# %%
plt.scatter(norm_sk['DENS_DEM'], norm_sk['NRO_EMP'], color='red')
plt.title('Número empresas Vs Densidade demográfica', fontsize=12)
plt.xlabel('Densidade demográfica', fontsize=12)
plt.ylabel('Número empresas', fontsize=12)
plt.grid(True)
plt.show()

# %%
#previsão

# %%
import sklearn.model_selection as ms
import sklearn.linear_model as lm
from sklearn.metrics import r2_score
import statsmodels as sm

# %%
x = norm_sk.iloc[:, 1:-1].values
y = norm_sk.iloc[:, -1].values

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test= ms.train_test_split(x,y,test_size=0.2,random_state=0)

# %%
print("x_train:",x_train.shape)
print("x_test:",x_test.shape)
print("y_train:",y_train.shape)
print("y_test:",y_test.shape)
# Out:
# x_train: (4456, 8)
# x_test: (1114, 8)
# y_train: (4456,)
# y_test: (1114,)

# %%
regressor = lm.LinearRegression()
regressor.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(x_test)
print(y_pred)
# Out:
# [ 0.34576771 -0.11324113  0.03610741 ...  4.90053124 -0.33644274
#   4.40822206]

# %%
plt.scatter(y_test,y_pred, color='blue');
plt.xlabel('Atual');
plt.ylabel('Previsão')
plt.show()

# %%
sns.regplot(x=y_test,y=y_pred,ci=None,color ='pink');

# %%
previsao=pd.DataFrame({'Valor atual':y_test,'Previsão':y_pred,'Diferença':y_test-y_pred})
print(previsao.head(20))
# Out:
#     Valor atual  Previsão  Diferença
# 0         1.000     0.346      0.654
# 1         0.000    -0.113      0.113
# 2         0.000     0.036     -0.036
# 3         0.000    -0.025      0.025
# 4         0.000    -0.608      0.608
# 5         1.000     0.518      0.482
# 6         0.000    -0.038      0.038
# 7         2.000     0.524      1.476
# 8         8.000     3.189      4.811
# 9         0.000    -0.451      0.451
# 10        5.000     3.705      1.295
# 11       19.000     5.230     13.770
# 12        3.000     2.544      0.456
# 13        1.000    -0.904      1.904
# 14        3.000     2.957      0.043
# 15        0.000    -0.678      0.678
# 16        0.000    -0.546      0.546
# 17        4.000     5.835     -1.835
# 18        0.000     0.263     -0.263
# 19        2.000    -0.143      2.143

# %%
previsao=pd.DataFrame({'Valor atual':y_test,'Previsão':y_pred,'Diferença':y_test-y_pred})
print(previsao.tail(20))
# Out:
#       Valor atual  Previsão  Diferença
# 1094        0.000    -0.465      0.465
# 1095        0.000    -0.198      0.198
# 1096        2.000     0.637      1.363
# 1097        0.000     0.933     -0.933
# 1098        1.000     2.426     -1.426
# 1099        0.000     1.451     -1.451
# 1100        2.000     1.939      0.061
# 1101        0.000     0.956     -0.956
# 1102        0.000    -0.205      0.205
# 1103        0.000    -0.430      0.430
# 1104        0.000    -0.083      0.083
# 1105        0.000     0.043     -0.043
# 1106        0.000    -0.009      0.009
# 1107        0.000    -0.385      0.385
# 1108        0.000    -0.285      0.285
# 1109        0.000    -0.401      0.401
# 1110        1.000     0.665      0.335
# 1111       17.000     4.901     12.099
# 1112        0.000    -0.336      0.336
# 1113        5.000     4.408      0.592

# %%
print('Intercept: \n', regressor.intercept_)
print('Coefficients: \n', regressor.coef_)
# Out:
# Intercept:
#  -4.87712154000512
# Coefficients:
#  [ 5.53577554e-05 -3.09704356e-04  6.79769048e+00  1.40573970e-05
#  -1.11065407e-01  4.09894733e-04  1.02958888e-01 -7.87146953e-08]

# %%
Accuracy=r2_score(y_test,y_pred)
print(" Accuracy of the model is %.3f" %Accuracy)
# Out:
#  Accuracy of the model is 0.763

# %%
plt.scatter(y_test,y_pred);
plt.xlabel('Actual');
plt.ylabel('Predicted')
plt.show()

# %%
#normalizar com formula

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import mean_absolute_error

# %%
tabelas = ['variaveis']
variaveis = pd.read_excel('Dados_-_novo.xlsx', engine="openpyxl")

# %%
variaveis["NRO_EMP"] = variaveis["NRO_EMP"].replace('0', 1.697)
print(variaveis.isnull().sum())
# Out:
# MUNICIPIO         0
# POP_EST           0
# DENS_DEM          0
# IDHM              0
# PIBCAP            0
# MASSA_PCAP        0
# CUSTO_UNIM        0
# MASSA_PCAP_POP    0
# DESP_TOT_RSU      0
# NRO_EMP           0
# dtype: int64

# %%
sns.displot(variaveis['IDHM'])

# %%
sns.displot(variaveis['POP_EST'])

# %%
norm_form = variaveis.copy() #normalizacao

# %%
for col in ['POP_EST','DENS_DEM','IDHM','PIBCAP','MASSA_PCAP','CUSTO_UNIM','MASSA_PCAP_POP','DESP_TOT_RSU']:
    norm_form[col]= (norm_form[col] - norm_form[col].mean()) / norm_form[col].std()

# %%
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %%
sns.displot(norm_form['IDHM'])

# %%
sns.displot(norm_form['POP_EST'])

# %%
import sklearn.model_selection as ms
import sklearn.linear_model as lm
from sklearn.metrics import mean_squared_error, r2_score

# %%
x = norm_form.iloc[:, 1:-1].values
y = norm_form.iloc[:, -1].values

# %%
x_train,x_test,y_train,y_test= ms.train_test_split(x,y,test_size=0.2,random_state=0)

# %%
print("x_train:",x_train.shape)
print("x_test:",x_test.shape)
print("y_train:",y_train.shape)
print("y_test:",y_test.shape)
# Out:
# x_train: (4456, 8)
# x_test: (1114, 8)
# y_train: (4456,)
# y_test: (1114,)

# %%
regressor = lm.LinearRegression()
regressor.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(x_test)
print(y_pred)
# Out:
# [ 0.34576771 -0.11324113  0.03610741 ...  4.90053124 -0.33644274
#   4.40822206]

# %%
plt.scatter(y_test,y_pred, color='green');
plt.xlabel('Atual');
plt.ylabel('Previsão')
plt.show()

# %%
sns.regplot(x=y_test,y=y_pred,ci=None,color ='red');

# %%
previsao=pd.DataFrame({'Valor atual':y_test,'Previsão':y_pred,'Diferença':y_test-y_pred})
print(previsao.head(20))
# Out:
#     Valor atual  Previsão  Diferença
# 0         1.000     0.346      0.654
# 1         0.000    -0.113      0.113
# 2         0.000     0.036     -0.036
# 3         0.000    -0.025      0.025
# 4         0.000    -0.608      0.608
# 5         1.000     0.518      0.482
# 6         0.000    -0.038      0.038
# 7         2.000     0.524      1.476
# 8         8.000     3.189      4.811
# 9         0.000    -0.451      0.451
# 10        5.000     3.705      1.295
# 11       19.000     5.230     13.770
# 12        3.000     2.544      0.456
# 13        1.000    -0.904      1.904
# 14        3.000     2.957      0.043
# 15        0.000    -0.678      0.678
# 16        0.000    -0.546      0.546
# 17        4.000     5.835     -1.835
# 18        0.000     0.263     -0.263
# 19        2.000    -0.143      2.143

# %%
previsao=pd.DataFrame({'Valor atual':y_test,'Previsão':y_pred,'Diferença':y_test-y_pred})
print(previsao.tail(20))
# Out:
#       Valor atual  Previsão  Diferença
# 1094        0.000    -0.465      0.465
# 1095        0.000    -0.198      0.198
# 1096        2.000     0.637      1.363
# 1097        0.000     0.933     -0.933
# 1098        1.000     2.426     -1.426
# 1099        0.000     1.451     -1.451
# 1100        2.000     1.939      0.061
# 1101        0.000     0.956     -0.956
# 1102        0.000    -0.205      0.205
# 1103        0.000    -0.430      0.430
# 1104        0.000    -0.083      0.083
# 1105        0.000     0.043     -0.043
# 1106        0.000    -0.009      0.009
# 1107        0.000    -0.385      0.385
# 1108        0.000    -0.285      0.285
# 1109        0.000    -0.401      0.401
# 1110        1.000     0.665      0.335
# 1111       17.000     4.901     12.099
# 1112        0.000    -0.336      0.336
# 1113        5.000     4.408      0.592

# %%
print('Intercept:', regressor.intercept_)
print('Coefficients:', regressor.coef_)
# Out:
# Intercept: 1.6803726847402793
# Coefficients: [12.4160887  -0.17710757  0.48919548  0.3407297  -0.06138512  0.05439733
#   0.0534427  -3.68390489]

# %%
Accuracy=r2_score(y_test,y_pred)
print(" Accuracy of the model is %.3f" %Accuracy)
# Out:
#  Accuracy of the model is 0.763

# %%
print(mean_absolute_error(y_test, y_pred)) #média de valores absolutos de cada erros de previsão em todas instâncias do teste
# Out:
# 1.1341795991867905

# %%
print(metrics.mean_squared_error(y_test, y_pred)) #média dos erros quadráticos de previsão em todas instâncias do teste
# Out:
# 8.0442684230175

# %%
rootMeanSqErr = np.sqrt(metrics.mean_squared_error(y_test, y_pred)) #desvio padrão dos erros da previsão
print(rootMeanSqErr)
# Out:
# 2.836241954244648
